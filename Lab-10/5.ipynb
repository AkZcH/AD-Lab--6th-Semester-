# %%
import numpy as np

A = np.array([3,4,1])
B = np.array([7,1,5])

euclidean = np.linalg.norm(A-B)
manhattan = np.sum(np.abs(A-B))
minkowski = np.power(np.sum(np.abs(A-B)**3), 1/3)

cosine = np.dot(A,B) / (np.linalg.norm(A)*np.linalg.norm(B))

print("Euclidean:", euclidean)
print("Manhattan:", manhattan)
print("Minkowski (p=3):", minkowski)
print("Cosine similarity:", cosine)
# Out:
# Euclidean: 6.4031242374328485
# Manhattan: 11
# Minkowski (p=3): 5.371685354944832
# Cosine similarity: 0.6793662204867574
