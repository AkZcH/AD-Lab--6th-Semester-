# %%
import numpy as np

demand = np.array([65, 66, 67, 67, 68, 69, 70, 72])
price  = np.array([67, 68, 65, 68, 72, 72, 69, 71])

r = np.corrcoef(demand, price)[0, 1]

print("Correlation coefficient (r):", r)
# Out:
# Correlation coefficient (r): 0.6030226891555273
