# %%
import numpy as np

data = np.array([12, 23, 31, 15, 26, 24, 16, 23])

mean = np.mean(data)

mad = np.mean(np.abs(data - mean))

print("Mean:", mean)
print("MAD:", mad)
# Out:
# Mean: 21.25
# MAD: 5.1875
