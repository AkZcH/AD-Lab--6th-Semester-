# %%
for model_name, hf_id in MODELS.items():
    tokenizer, model = load_model(hf_id)
    for example in dataset:
        scores = score_example(example, tokenizer, model)
    save_results(model_name)
