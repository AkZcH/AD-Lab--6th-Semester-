# %%
MODELS = {
    "bert-base": "bert-base-uncased",
    "roberta-base": "roberta-base",
    "distilbert-base": "distilbert-base-uncased"
}

DATASET = "McGill-NLP/stereoset"
SPLIT = "dev"
MAX_EXAMPLES = None   # or small number for testing
